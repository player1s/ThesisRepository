# %%
import pandas as pd
pd.set_option('display.max_columns', None)
path = "data/142638_game_2023-12-11_12h32.36.799.csv"
data = pd.read_csv(path)
data
# Out:
#    trials_7.thisRepN  trials_7.thisTrialN  trials_7.thisN  trials_7.thisIndex  \
# 0                NaN                  NaN             NaN                 NaN
# 1                0.0                  0.0             0.0                 0.0
# 2                1.0                  0.0             1.0                 0.0
# 3                NaN                  NaN             NaN                 NaN
#
#    text_2.started  key_resp.started key_resp.keys  key_resp.rt  \
# 0       10.813365         10.813365         space     1.049066
# 1             NaN               NaN           NaN          NaN
# 2             NaN               NaN           NaN          NaN
# 3             NaN               NaN           NaN          NaN
#
#    text_5.started  slider.started  \
# 0             NaN             NaN
# 1       11.925436       11.925436
# 2       13.207697       13.207697
# 3             NaN             NaN
#
#                                                 FAI1 slider.response  \
# ...
