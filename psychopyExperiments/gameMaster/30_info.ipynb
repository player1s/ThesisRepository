# %%
import pandas as pd
pd.set_option('display.max_columns', None)
path = "data/682748_game_2023-12-11_12h30.35.527.csv"
data = pd.read_csv(path)
data
# Out:
#    trials_7.thisRepN  trials_7.thisTrialN  trials_7.thisN  trials_7.thisIndex  \
# 0                NaN                  NaN             NaN                 NaN
# 1                0.0                  0.0             0.0                 0.0
# 2                1.0                  0.0             1.0                 0.0
# 3                NaN                  NaN             NaN                 NaN
#
#    text_2.started  key_resp.started key_resp.keys  key_resp.rt  \
# 0       12.134448         12.134448         space    60.067833
# 1             NaN               NaN           NaN          NaN
# 2             NaN               NaN           NaN          NaN
# 3             NaN               NaN           NaN          NaN
#
#    text_5.started  slider.started  slider.response  slider.rt  text_4.started  \
# 0             NaN             NaN              NaN        NaN             NaN
# 1       72.256358       72.256358              5.0   4.692206             NaN
# ...
